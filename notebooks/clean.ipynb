# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
full_data = pd.read_pickle('../data/processed/full_data.pkl')

# %%
# newyork_2015 = pd.DataFrame(full_data.loc[(full_data['year']==2015) & (full_data['region'] == 'New York')].groupby('week')['sales'].sum()).reset_index()
full_data = full_data.drop(columns=['yearweek', 'days', 'd'])

# %%
full_data['event'] = full_data['event'].fillna(False)
full_data.loc[full_data['event'] != False, 'event'] = True
# full_data[full_data['event'] != False].head(100)
# Out:
#                     item    category    department store_code    region  \
# 243927  ACCESORIES_1_008  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 243928  ACCESORIES_1_009  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 243929  ACCESORIES_1_010  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 243931  ACCESORIES_1_012  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 243934  ACCESORIES_1_015  ACCESORIES  ACCESORIES_1      NYC_1  New York
# ...                  ...         ...           ...        ...       ...
# 244194  ACCESORIES_1_282  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 244198  ACCESORIES_1_286  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 244200  ACCESORIES_1_288  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 244201  ACCESORIES_1_289  ACCESORIES  ACCESORIES_1      NYC_1  New York
# 244202  ACCESORIES_1_290  ACCESORIES  ACCESORIES_1      NYC_1  New York
#
#         sales        date weekday  weekday_int event  year  month  day week  \
# ...

# %%
full_data['total_sales'] = full_data['sales'] * full_data['sell_price']

# %%
full_data.to_pickle('../data/processed/full_data.pkl')
