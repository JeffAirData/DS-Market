# %%
import pandas as pd
import numpy as np

# %%
full_data = pd.read_pickle('../data/processed/full_data.pkl')

# %%
# newyork_2015 = pd.DataFrame(full_data.loc[(full_data['year']==2015) & (full_data['region'] == 'New York')].groupby('week')['sales'].sum()).reset_index()
full_data = full_data.drop(columns=['yearweek'])

# %%
full_data.head(10)
# Out:
#                item    category    department store_code    region days  \
# 0  ACCESORIES_1_008  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 1  ACCESORIES_1_009  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 2  ACCESORIES_1_010  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 3  ACCESORIES_1_012  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 4  ACCESORIES_1_015  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 5  ACCESORIES_1_016  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 6  ACCESORIES_1_022  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 7  ACCESORIES_1_023  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 8  ACCESORIES_1_028  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
# 9  ACCESORIES_1_029  ACCESORIES  ACCESORIES_1      NYC_1  New York  d_3
#
#    sales        date weekday  weekday_int    d event  year  month  day  week  \
# 0      0  2011-01-31  Monday            3  d_3   NaN  2011      1   31     5
# ...

# %%
full_data[(full_data['region'] == 'New York') & (full_data['item'] == 'ACCESORIES_1_028')]['sell_price'].unique()
# Out:
# array([ 8.8711,  9.2834, 10.6134,  7.1288,  9.5494], dtype=float32)

# %%
newyork = full_data[full_data['region'] == 'New York']
boston = full_data[full_data['region'] == 'Boston']
philadelphia = full_data[full_data['region'] == 'Philadelphia']

# %%
newyork['store_code'].unique()
# Out:
# array(['NYC_1', 'NYC_2', 'NYC_3', 'NYC_4'], dtype=object)

# %%
store = newyork[newyork['store_code'] == 'NYC_1']
itens = store['item'].unique()
sales_ranking = store.groupby(['item'])
# Out:
# (3049,)
